# %% [markdown]
# ![IIT_original.png](attachment:IIT_original.png)
# ## <center>  Data Structures and Algorithms (CIT1C14)(CCE1C01)</center>
# ## <center>  Lab 11e - List and Tuple</center>

# %% [markdown]
# ### <font color=red>1. Watch the following videos and learn about file I/O

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='9KJ-XeQ6ZlI'
YouTubeVideo(id=id,width=600,height=300)

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='0t4rvnySKR4'
YouTubeVideo(id=id,width=600,height=300)

# %% [markdown]
# ### <font color=red>2. Watch the following video on list and tuple data structures

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='fXRxHrDhQuI?'
YouTubeVideo(id=id,width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/fXRxHrDhQuI?"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### <font color=orange>3. [Do lab11e quiz01 here](https://tplms.polite.edu.sg/d2l/lms/quizzing/user/quiz_summary.d2l?qi=768124&ou=372602)

# %% [markdown]
# ### <font color=red>*4. Given a list containing duplicates, how would you remove the duplicates? Use only mehtods available to list. One possible implementation is shown below. Complete the missing lines

# %% [markdown]
# ### <font color=red>5. Try other ways of removing duplicates. One possible implementation is to use set()

# %% [markdown]
# ### <font color=red>*6. Use %%timeit to compare your implementations with set() method. Can your best algorithm beat set() implementation?
