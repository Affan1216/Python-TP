# %% [markdown]
# ![IIT_original.png](attachment:IIT_original.png)
# ## <center>  Data Structures and Algorithms (CIT1C14)(CCE1C01)</center>
# ## <center>  Lab 4e - Analysis of Algorithms </center>

# %% [markdown]
# ### <font color=red> 1 Watch the following videos

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='8jafWpXPMBs'
YouTubeVideo(id=id,width=600,height=300)

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='kS_gr2_-ws8'
YouTubeVideo(id=id,width=600,height=300)

# %% [markdown]
# ### <font color=orange> 2 Do the self-check quiz (Lab4e Quiz) to test your understanding [Lab 4e quiz](https://tplms.polite.edu.sg/d2l/lms/quizzing/user/quiz_summary.d2l?qi=768120&ou=372602). It is not graded.
