# %% [markdown]
# ![IIT_original.png](attachment:IIT_original.png)
# ## <center>  Data Structures and Algorithms (CIT1C14)(CCE1C01)</center>
# ### <center>  Lab 12e - List Comprehension </center>

# %% [markdown]
# ### <font color=red>Watch the following video on list comprehension

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='EqAEyleLaVA?'
YouTubeVideo(id=id,width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/EqAEyleLaVA?"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Get Generative AI (Gen AI) to teach me on List Comprehension
# ![image.png](attachment:image.png)

# %% [raw]
# Use the following prompt to prompt ChatGPT
# I am a student who is currently studying data structures and algorithms, with a primary focus on Python as my chosen programming language. In my recent coursework, we have been exploring Python lists. I've recently heard about a concept called 'list comprehension,' but I lack a clear understanding of this topic. I am eager to learn, and I kindly request you to take on the role of a patient teacher. Please explain list comprehension in a simple and easy-to-understand manner. It would be immensely helpful if you could illustrate the concept with numerous Python code snippets. To facilitate my learning, could you present the lessons in manageable chunks, allowing me time to grasp each segment before moving on to the next?

# %%
# Traditional approach
numbers = [1, 2, 3, 4, 5]
squared = []
for num in numbers:
    squared.append(num ** 2)

# Using list comprehension
#squared = [num ** 2 for num in numbers]
print(squared)
# Out:
# [1, 4, 9, 16, 25]
